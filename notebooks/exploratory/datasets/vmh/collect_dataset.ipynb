# %%
# !pwd
# Out:
# /home/user/Documents/Students/Sobhan Ahmadian/Projects/SKGNMDA/notebooks/exploratory/datasets/vmh

# %%
cd /home/user/Documents/Students/Sobhan Ahmadian/Projects/SKGNMDA
# Out:
# /home/user/Documents/Students/Sobhan Ahmadian/Projects/SKGNMDA
# /home/user/Documents/Students/Sobhan Ahmadian/Projects/SKGNMDA/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# # Collect Data

# %%
from src.data.data_collectors import VMHDataCollectorManager

# %%
manager = VMHDataCollectorManager()

# %%
tables_data = manager.get_tables_list()

# %%
tables_data
# Out:
# {'metabolites': 'http://www.vmh.life/_api/metabolites/',
#  'reactions': 'http://www.vmh.life/_api/reactions/',
#  'smatrix': 'http://www.vmh.life/_api/smatrix/',
#  'genes': 'http://www.vmh.life/_api/genes/',
#  'rxntomodel': 'http://www.vmh.life/_api/rxntomodel/',
#  'reconstructions': 'http://www.vmh.life/_api/reconstructions/',
#  'diseases': 'http://www.vmh.life/_api/diseases/',
#  'biomarkers': 'http://www.vmh.life/_api/biomarkers/',
#  'evidence': 'http://www.vmh.life/_api/evidence/',
#  'microbes': 'http://www.vmh.life/_api/microbes/',
#  'metdeltags': 'http://www.vmh.life/_api/metdeltags/',
#  'reacdeltags': 'http://www.vmh.life/_api/reacdeltags/',
#  'fermcarbon': 'http://www.vmh.life/_api/fermcarbon/',
#  'compartments': 'http://www.vmh.life/_api/compartments/',
#  'foods': 'http://www.vmh.life/_api/foods/',
#  'components': 'http://www.vmh.life/_api/components/',
#  'subsystems': 'http://www.vmh.life/_api/subsystems/',
#  'diets': 'http://www.vmh.life/_api/diets/',
# ...

# %%
selected_tables = ['rxntomodel',
                   ]
selected_tables_data = dict((k, tables_data[k]) for k in selected_tables)

selected_tables_data
# Out:
# {'rxntomodel': 'http://www.vmh.life/_api/rxntomodel/'}

# %%
manager.update_tables(selected_tables_data)
# Out:
# 2023-12-13 16:23:22,171 [INFO] request with url http://www.vmh.life/_api/rxntomodel/ completed.
# 2023-12-13 16:23:22,878 [INFO] request with url http://www.vmh.life/_api/rxntomodel/?page=2 completed.
# 2023-12-13 16:23:23,811 [INFO] request with url http://www.vmh.life/_api/rxntomodel/?page=3 completed.
# 2023-12-13 16:23:24,525 [INFO] request with url http://www.vmh.life/_api/rxntomodel/?page=4 completed.
# 2023-12-13 16:23:25,146 [INFO] request with url http://www.vmh.life/_api/rxntomodel/?page=5 completed.
# 2023-12-13 16:23:25,767 [INFO] request with url http://www.vmh.life/_api/rxntomodel/?page=6 completed.
# 2023-12-13 16:23:26,507 [INFO] request with url http://www.vmh.life/_api/rxntomodel/?page=7 completed.
# 2023-12-13 16:23:27,258 [INFO] request with url http://www.vmh.life/_api/rxntomodel/?page=8 completed.
# 2023-12-13 16:23:28,133 [INFO] request with url http://www.vmh.life/_api/rxntomodel/?page=9 completed.
# ...
